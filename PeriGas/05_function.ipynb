# %%
import scanpy as sc
import numpy as np
import pandas as pd

# %%
# adata = sc.read_h5ad('/mnt/yiming/nfs_share/hema_wave/perigas-bgi-rna-annotated-v2.h5ad')

# %%
phago_genesets = {
    'Core Receptors': ['ITGAM', 'MERTK', 'MSR1'],
    'Engulfment': ['RAC1', 'SYK', 'DOCK2'],
    'Lysosomal': ['LAMP1', 'CTSD', 'ATP6V0A1'],
    'Efferocytosis': ['MERTK', 'GAS6', 'MFGE8'],
    'Killing': [ 'LYZ', 'NOS2']
}

sc.pl.dotplot(adata, phago_genesets, groupby=['CellType_man'], 
              var_group_rotation=20, 
              # dendrogram=True,
             standard_scale='var', show=False)
# Out:
# {'mainplot_ax': <Axes: >,
#  'gene_group_ax': <Axes: >,
#  'size_legend_ax': <Axes: title={'center': 'Fraction of cells\nin group (%)'}>,
#  'color_legend_ax': <Axes: title={'center': 'Mean expression\nin group'}>}

# %%
phago_genesets = {
    'Core Receptors': ['ITGAM', 'MERTK', 'MSR1'],
    'Engulfment': ['RAC1', 'SYK', 'DOCK2'],
    'Lysosomal': ['LAMP1', 'CTSD', 'ATP6V0A1'],
    'Efferocytosis': ['MERTK', 'GAS6', 'MFGE8'],
    'Killing': [ 'LYZ', 'NOS2']
}

sc.pl.dotplot(adata, phago_genesets, groupby=['group'], 
              var_group_rotation=20, 
              # dendrogram=True,
             standard_scale='var', show=False)
# Out:
# {'mainplot_ax': <Axes: >,
#  'gene_group_ax': <Axes: >,
#  'size_legend_ax': <Axes: title={'center': 'Fraction of cells\nin group (%)'}>,
#  'color_legend_ax': <Axes: title={'center': 'Mean expression\nin group'}>}

# %%
phago_genesets = {
    'Core Receptors': ['ITGAM', 'MERTK', 'MSR1'],
    'Engulfment': ['RAC1', 'SYK', 'DOCK2'],
    'Lysosomal': ['LAMP1', 'CTSD', 'ATP6V0A1'],
    'Efferocytosis': ['MERTK', 'GAS6', 'MFGE8'],
    'Killing': [ 'LYZ', 'NOS2']
}

sc.pl.dotplot(adata_mesery, phago_genesets, groupby=['group'], 
              var_group_rotation=20, 
              # dendrogram=True,
             standard_scale='var', show=False)
# Out:
# {'mainplot_ax': <Axes: >,
#  'gene_group_ax': <Axes: >,
#  'size_legend_ax': <Axes: title={'center': 'Fraction of cells\nin group (%)'}>,
#  'color_legend_ax': <Axes: title={'center': 'Mean expression\nin group'}>}

# %%
sc.pl.dotplot(adata, groupby=['CellType_man'], var_names=['EGF', 'EGFR', 'STAT3', 'MAPK1', 
             'TGFB1', 'TGFBR1', 'TNF', 'TNFRSF1A', 
            'NFKB1', 'ZEB1', 'ZEB2', 'TWIST1', 'SNAI1', 'SNAI2', 
            'PRRX1', 'FOXC2', 'SOX4', 'SOX9', 
            'VIM', 'CDH2', 'FN1', 'MMP2', 'MMP9', 'LOX', 'TGM2'], 
    dendrogram=False,  
    cmap='Reds',
    var_group_rotation=0,
    standard_scale='var',
    swap_axes=False)

# %%
sc.pl.dotplot(adata, groupby=['group'], var_names=['EGF', 'EGFR', 'STAT3', 'MAPK1', 
             'TGFB1', 'TGFBR1', 'TNF', 'TNFRSF1A', 
            'NFKB1', 'ZEB1', 'ZEB2', 'TWIST1', 'SNAI1', 'SNAI2', 
            'PRRX1', 'FOXC2', 'SOX4', 'SOX9', 
            'VIM', 'CDH2', 'FN1', 'MMP2', 'MMP9', 'LOX', 'TGM2'], 
    dendrogram=False,  
    cmap='Reds',
    var_group_rotation=0,
    standard_scale='var',
    swap_axes=False)

# %%
sc.pl.dotplot(adata_mesery, groupby=['group'], var_names=['EGF', 'EGFR', 'STAT3', 'MAPK1', 
             'TGFB1', 'TGFBR1', 'TNF', 'TNFRSF1A', 
            'NFKB1', 'ZEB1', 'ZEB2', 'TWIST1', 'SNAI1', 'SNAI2', 
            'PRRX1', 'FOXC2', 'SOX4', 'SOX9', 
            'VIM', 'CDH2', 'FN1', 'MMP2', 'MMP9', 'LOX', 'TGM2'], 
    dendrogram=False,  
    cmap='Reds',
    var_group_rotation=0,
    standard_scale='var',
    swap_axes=False)

# %%
emt_genes = ['EGF', 'EGFR', 'STAT3', 'MAPK1', 
             'TGFB1', 'TGFBR1', 'TNF', 'TNFRSF1A', 
            'NFKB1', 'ZEB1', 'ZEB2', 'TWIST1', 'SNAI1', 'SNAI2', 
            'PRRX1', 'FOXC2', 'SOX4', 'SOX9', 
            'VIM', 'CDH2', 'FN1', 'MMP2', 'MMP9', 'LOX', 'TGM2']
sc.tl.score_genes(adata, emt_genes, score_name='EMT')

wnt_genes = ['WNT1', 'WNT2', 'WNT3', 'WNT3A', 'WNT4', 'WNT5A', 'WNT7A', 'WNT8A', 'WNT11',  
             'FZD1', 'FZD2', 'FZD3', 'FZD4', 'FZD5', 'FZD6', 'FZD7', 'FZD8', 'FZD9', 'FZD10',  
             'LRP5', 'LRP6', 'DVL1', 'DVL2', 'DVL3',  
             'AXIN1', 'AXIN2', 'APC', 'GSK3B', 'CTNNB1', 'TCF7', 'TCF7L1', 'TCF7L2', 'LEF1'] 
sc.tl.score_genes(adata, wnt_genes, score_name='WNT')

hedgehog_genes = ['SHH', 'IHH', 'DHH',  
                 'PTCH1', 'PTCH2', 'SMO',  
                 'GLI1', 'GLI2', 'GLI3',  
                 'SUFU', 'HHIP']  
sc.tl.score_genes(adata, hedgehog_genes, score_name='hedgehog')

tgf_bmp_genes = ['TGFB1', 'TGFB2', 'TGFB3',  
                'BMP2', 'BMP4', 'BMP7', 'BMP9',  
                'SMAD1', 'SMAD2', 'SMAD3', 'SMAD4', 'SMAD5', 'SMAD9',  
                'TGFBR1', 'TGFBR2', 'BMPR1A', 'BMPR1B', 'BMPR2',  
                'NOG', 'CHRD', 'GREM1', 'FST']  
sc.tl.score_genes(adata, tgf_bmp_genes, score_name='TGF/BMP')

notch_genes = ['NOTCH1', 'NOTCH2', 'NOTCH3', 'NOTCH4',  
              'DLL1', 'DLL3', 'DLL4', 'JAG1', 'JAG2',  
              'RBPJ', 'HES1', 'HES5', 'HEY1', 'HEY2']  
sc.tl.score_genes(adata, notch_genes, score_name='NOTCH')

fgf_genes = ['FGF1', 'FGF2', 'FGF4', 'FGF8', 'FGF10',  
            'FGFR1', 'FGFR2', 'FGFR3', 'FGFR4',  
            'GRB2', 'SOS1', 'RAS', 'RAF1', 'MAPK1', 'MAPK3']  
sc.tl.score_genes(adata, fgf_genes, score_name='FGF')

retinoic_acid_genes = ['RARA', 'RARB', 'RARG',  
                      'RXRA', 'RXRB', 'RXRG',  
                      'CYP26A1', 'CYP26B1', 'CYP26C1',  
                      'ALDH1A1', 'ALDH1A2', 'ALDH1A3']  
sc.tl.score_genes(adata, retinoic_acid_genes, score_name='RA')

nodal_genes = ['NODAL', 'LEFTY1', 'LEFTY2',  
              'ACVR1B', 'ACVR2A', 'ACVR2B',  
              'SMAD2', 'SMAD3', 'SMAD4',  
              'PITX2', 'FOXH1']  
sc.tl.score_genes(adata, nodal_genes, score_name='NODAL')

jak_stat_genes = ['JAK1', 'JAK2', 'JAK3', 'TYK2',  
                 'STAT1', 'STAT2', 'STAT3', 'STAT4', 'STAT5A', 'STAT5B', 'STAT6',  
                 'IL6ST', 'SOCS1', 'SOCS3', 'PIAS1']  
sc.tl.score_genes(adata, jak_stat_genes, score_name='JAK/STAT')
# Out:
# computing score 'EMT'
#     finished: added
#     'EMT', score of gene set (adata.obs).
#     800 total control genes are used. (0:00:02)
# computing score 'WNT'
#     finished: added
#     'WNT', score of gene set (adata.obs).
#     748 total control genes are used. (0:00:01)
# computing score 'hedgehog'
#     finished: added
#     'hedgehog', score of gene set (adata.obs).
#     500 total control genes are used. (0:00:01)
# computing score 'TGF/BMP'
# WARNING: genes are not in var_names and ignored: Index(['BMP9'], dtype='object')
#     finished: added
#     'TGF/BMP', score of gene set (adata.obs).
#     649 total control genes are used. (0:00:01)
# computing score 'NOTCH'
#     finished: added
#     'NOTCH', score of gene set (adata.obs).
#     550 total control genes are used. (0:00:01)
# computing score 'FGF'
# WARNING: genes are not in var_names and ignored: Index(['RAS'], dtype='object')
#     finished: added
#     'FGF', score of gene set (adata.obs).
#     450 total control genes are used. (0:00:01)
# computing score 'RA'
#     finished: added
#     'RA', score of gene set (adata.obs).
#     499 total control genes are used. (0:00:01)
# computing score 'NODAL'
#     finished: added
#     'NODAL', score of gene set (adata.obs).
#     299 total control genes are used. (0:00:01)
# computing score 'JAK/STAT'
#     finished: added
#     'JAK/STAT', score of gene set (adata.obs).
#     400 total control genes are used. (0:00:01)

# %%
scores = ['EMT', 'WNT', 'hedgehog', 'TGF/BMP', 'NOTCH', 'FGF', 'RA', 'JAK/STAT']
sc.pl.dotplot(adata, groupby=['CellType_man'], var_names=scores, standard_scale='var')

# %%
adata_mesery = adata[adata.obs['CellType_man']=='Mes-Ery']

# %%
scores = ['EMT', 'WNT', 'hedgehog', 'TGF/BMP', 'NOTCH', 'FGF', 'RA', 'JAK/STAT']
sc.pl.dotplot(adata_mesery, groupby=['group'], var_names=scores, standard_scale='var')

# %%
scores = ['EMT', 'WNT', 'hedgehog', 'TGF/BMP', 'NOTCH', 'FGF', 'RA', 'JAK/STAT']
sc.pl.dotplot(adata, groupby=['group'], var_names=scores, standard_scale='var')
